# %% [markdown]
# Resumen
#
# 1.
#
# La clase \w es equivalente a:
#
# [a-zA-Z0-9_]
#
# 2.
#
# ¿Cuál de los siguientes casos de uso considerarías para usar S3?
#
# Almacenar logs para proyectos de BigData.
#
# 3.
#
# ¿Con cuál de los siguientes comandos se puede escribir en un archivo llamado prueba.txt sin utilizar un programa externo?
#
# vim texto >> prueba.txt `************MAL****************`
#
# echo texto >> prueba.txt `************CORRECTA****************`
#
# 4.
#
# ¿Cómo se llama la librería de Python para interactuar con los servicios de AWS ?
#
# Boto3
#
# 5.
#
# ¿Cuál es un ejemplo de base de datos optimizada para búsqueda?
#
# MongoDB `************MAL****************`
#
# Big Query `************CORRECTA****************`
#
# `*************************************************************************************************************************`
#
# La optimización para búsquedas puede depender del tipo de búsqueda que estés realizando y de los requisitos específicos de tu aplicación. Aquí hay algunas consideraciones para cada una de las opciones mencionadas:
#
# 1. **BigQuery (Opción A):** BigQuery es un servicio de almacenamiento y análisis de datos de Google Cloud Platform. Está optimizado para consultas analíticas complejas sobre conjuntos de datos grandes. Es eficiente para análisis de datos, pero si tu caso principal es la búsqueda, podría no ser la mejor opción.
#
# 2. **Neo4J (Opción B):** Neo4j es una base de datos de grafos y es excelente para casos donde las relaciones entre los datos son críticas, como en redes sociales o recomendaciones. Si tu búsqueda implica seguir relaciones complejas entre datos, Neo4j podría ser una elección adecuada.
#
# 3. **Cassandra (Opción C):** Cassandra es una base de datos NoSQL distribuida diseñada para manejar grandes cantidades de datos en clústeres de servidores. Es eficaz para búsquedas rápidas en datos distribuidos y escalabilidad horizontal. Sin embargo, es más adecuada para casos de uso como series temporales o acceso rápido a datos por clave.
#
# 4. **MongoDB (Opción D):** MongoDB es una base de datos NoSQL que es buena para casos de uso donde la flexibilidad del esquema y la escalabilidad horizontal son esenciales. Puede ser eficiente para ciertos tipos de búsquedas, pero su rendimiento dependerá de la naturaleza exacta de las consultas.
#
# 5. **Firestore (Opción E):** Firestore es una base de datos NoSQL en tiempo real de Firebase, adecuada para aplicaciones web y móviles. Está diseñada para ser eficiente en la sincronización de datos en tiempo real y para manejar grandes cantidades de datos en aplicaciones en tiempo real. Es especialmente útil cuando necesitas una respuesta rápida a cambios de datos.
#
# En resumen, la elección entre estas opciones dependerá de la naturaleza específica de tus necesidades de búsqueda, la complejidad de tus datos y otros requisitos específicos de tu aplicación.
#
# `*************************************************************************************************************************`
# 6.
#
# ¿A que se traducen las entidades de un RDBMS en Firestore?
#
# Documentos `************MAL****************`
#
# Colecciones `************CORRECTA****************`
#
# 7.
#
# Para que dos personas trabajen en paralelo sobre el mismo archivo se recomienda:
#
# Una rama independiente por cada persona y sus cambios que luego con verificación se hace merge a master.
#
# 8.
#
# Las extensiones nos permiten:
#
# Extender la funcionalidad de PostgreSQL.
#
# 9.
#
# ¿Cuál de las siguientes afirmaciones es verdadera?
#
# El orden de las instrucciones en el Dockerfile no afecta el uso del cache de build, solo los archivos que son utilizados o generados en cada capa. `************MAL****************`
#
# El cache de build es afectado por tanto el orden de las instrucciones en el Dockerfile como también por los archivos que son utilizados o generado en cada instrucción del mismo. `************CORRECTA????****************`
#
# 10.
#
# Las funciones de agregación se usan en conjunto con la sentencia:
#
# GROUP BY
#
# 11.
#
# Al usar gráficas de tablas se recomienda:
#
# Acompañarlas con otro data viz para brindar mayor claridad a los datos.
#
# 12.
#
# ¿Porqué es importante contar historias?
#
# Los datos sin historias son solo números y texto.
#
# 13.
#
# ¿Qué hace el comando pwd?
#
# Imprime la ruta del directorio actual de trabajo.
#
# 14.
#
# El comando chmod u=rwx,go=r mi_archivo ¿qué permisos otorga?
#
# Otorga permisos de lectura, escritura y ejecución al usuario. Solo otorga permiso de lectura a los grupos y a otros.
#
# 15.
#
# ¿Cuál es el comando de NumPy para crear un array de n elementos con valores de cero (0)?
#
# np.zeros()
#
# 16.
#
# Con este comando de Seaborn se pueden crear distintos tipos de datos orientados a gráficos de relación:
#
# sns.relationplot `************MAL****************`
#
# sns.relplot `************CORRECTA****************`
#
# 17.
#
# ¿Cuál de las siguientes es una práctica recomendada de IAM?
#
# No use la cuenta de usuario raíz
#
# 18.
#
# ¿Cuál de los siguientes elementos no es una medida de tendencia central?
#
# rango
#
# 19.
#
# ¿Por qué es importante jugar con el band width al realizar una gráfica de función de densidad de probabilidad?
#
# Jugar con el band width al realizar una gráfica de función de densidad de probabilidad permite obtener una distribución más
# suave o áspera. Permitiéndote encontrar nuevas zonas de interés en tus datos.
#
# 20.
#
# Los ExternalTaskSensor nos permiten:
#
# Esperar por el estado de una tarea que se encuentra en otro DAG
#
# 21.
#
# Dado el siguiente bloque de código:
#
# ![](preg_21_0.png)
#
# ¿Cuál de las siguientes respuestas con List Comprehension nos peermite obtener el mismo resultad con una sintaxis más corta?
#
# n = [i - 1 for i in range(1,6) if i <= 2]
#
# 22.
#
# ¿Cuál de las siguientes estructuras de datos es mutable?
#
# List
#
# 23.
#
# ¿Para qué sirven los operadores aritméticos en Python?
#
# Para ejecutar operaciones matemáticas fundamentales como suma, resta, multiplicación y división.
#
# 24.
#
# ¿Para qué se usa el operador not en Python?
#
# Para negar un valor booleano dentro del programa.
#
# 25.
#
# ¿Cuál es el resultado de la siguiente condicional en Python?
#
# ![](preg_25_0.png)
#
# Welcome to New York City
#
# 26.
#
# Al realizar cualquier tipo de imputación de datos deberás realizar una exploración y limpieza de datos. ¿Cuál de las siguientes acciones NO es un paso válido en este proceso?
#
# Eliminar todos los valores faltantes en el conjunto de datos sin previamente revisarlos.
#
# 27.
#
# ¿Qué es el Aggregation Framework de MongoDB?
#
# Es una forma extendida para hacer consultas en Mongo más potentes y complejas, usadas principalmente para analizar datos
#
# 28.
#
# ¿Cuál es el orden correcto de los 3 pasos de la metodología vista en el curso para modelar una base de datos en MongoDB?
#
# 1 - Identificar los requerimientos 2 - Identificar las entidades y relaciones 3 - Identificar y aplicar patrones
#
# 29.
#
# ¿Cuál es el rol encargado generalmente de la parte exploratoria de un dataset para encontrar valor?
#
# Data Scientist
#
# 30.
#
# Si quisieras usar repositorios privativos en un servidor Debian, ¿qué tendrías qué hacer?
#
# Se tienen que activar los non free repositories en el manejador de paquetes.

# %% [markdown]
# 1.
#
# ¿Cuál funcionalidad te permite utilizar los CDN de AWS para mejorar la carga de archivos a S3?
#
# Storage Gateway. `*****************MAL*****************`
#
# 2.
#
# Trabajas como arquitecto de soluciones para una universidad y te piden diseñar un sistema para que las tesis de grado puedan ser configuradas para que después del año de presentación queden guardadas teniendo en cuenta que son poco consultadas, tú quieres automatizar este proceso, ¿Qué funcionalidad usarías?
#
# Ciclo de vida de s3.
#
# 3.
#
# Al borrar nuestra RDS ¿qué sucede con los backups manuales?
#
# Se programa su borrado en 24 horas. `*****************MAL*****************`
#
# 4.
#
# DynamoDB es una base de datos relacional.
#
# Falso.
#
# 5.
#
# ¿Una vez creado un script antes de ejecutarlo se tiene que otorgar un permiso de ejecución, con cuál comando se realiza esta acción?
#
# chmod +x script.sh
#
# 6.
#
# Dentro del servicio de Developer Endpoint de Glue , ¿Qué tipos de notebooks puedes crear?
#
# Zeppelin y Sage Maker.
#
# 7.
#
# ¿Qué significa la “S” en SQL?
#
# Structured
#
# 8.
#
# ¿La terminal ideal para usar Git en Windows es?
#
# Git Bash o una terminal derivada de Linux
#
# 9.
#
# ¿Las llaves públicas son?
#
# Sistemas de cifrado básicos donde la misma llave puede cifrar y descifrar un mensaje. `*****************MAL*****************`
#
# 10.
#
# ¿Qué crean los tags en Git?
#
# Etiquetas para luego buscar qué tipo de archivos estaba usando y sus categorías. `*****************MAL*****************`
#
# 11.
#
# En la teoría de conjuntos, el INNER JOIN corresponde a:
#
# Intersección
#
# 12.
#
# ¿Qué formato debes usar si queremos ver la consulta equivalente a nuestra base de datos al momento de hacer Backup?
#
# Tar `*****************MAL*****************`
#
# 13.
#
# ¿Es posible actualizar la información en una réplica?
#
# Verdadero `*****************MAL*****************`
#
# 14.
#
# ¿Cómo extraemos un atributo de un tag?
#
# No se puede extraer el atributo de un tag, sólo se puede extraer el texto. `*****************MAL*****************`
#
# 15.
#
# Consigue comprimir los datos creando otra entidad en donde a cada valor de la columna se le asigna un índice único.
#
# Diccionario de bytes
#
# 16.
#
# Una de las desventajas del ordenamiento intercalado (Interleaved) es:
#
# La carga de datos es más lenta.
#
# 17.
#
# Cuando construimos una imagen, la cantidad total de sus capas es...
#
# La cantidad de capas de la imagen base y la cantidad de instrucciones en el Dockefile.
#
# 18.
#
# Se pueden usar subqueries solo en la cláusula FROM
#
# Falso
#
# 19.
#
# La shell o línea de comandos es:
#
# Un programa que nos ayuda a comunicarnos con nuestro sistema operativo.
#
# 20.
#
# Un tipo de mapeo numérico que causa una representación compacta es el:
#
# One-hot `*****************MAL*****************`
#
# 21.
#
# ¿Cuáles de los siguientes son beneficios válidos de usar la nube de AWS?
#
# Capacidad para globalizarse rápidamente.
#
# 22.
#
# ¿Podemos considerar el array como el objeto principal de NumPy?
#
# Verdadero
#
# 23.
#
# ¿Cuál de las siguientes es una práctica recomendada de IAM?
#
# No use la cuenta de usuario raíz
#
# 24.
#
# Un Cloud Practitioner está desarrollando una nueva aplicación y desea integrar funciones de los servicios de AWS
# directamente en la aplicación. ¿Cuál de las siguientes es la MEJOR herramienta para este propósito?
#
# AWS SDK
#
# 25.
#
# ¿Cuál de los siguientes es un principio de The Zen of Python?
#
# Bello es mejor que feo.
#
# 26.
#
# `pyjanitor` es una implementación del paquete de R `janitor`, y provee una API para limpieza de datos en Python. ¿Cuál de las siguientes funciones podríamos utilizar para exponer los valores faltantes implícitos?
#
# janitor.complete()
#
# 27.
#
# ¿Cuál es el método que nos permite insertar un documento en una colección?
# db.products.insertOne({...})
#
# 28.
#
# ¿Cuál es el objetivo del documento de Workload?
#
# Nos ayuda a identificar la carga de la base de datos tanto de lectura de escritura, las entidades, actores y observaciones encontradas en el caso de negocio.
#
# 29.
#
# Un sistema operativo Linux se puede subdividir en las siguientes capas:
#
# Hardware, kernel, shell y aplicaciones.
#
# 30.
#
# ¿Cuál es la diferencia entre el source y el target en una ETL?
#
# El source se refiere a la fuente de datos donde se extraen los datos para la transformación y carga en el target, que es el destino final de los datos.
